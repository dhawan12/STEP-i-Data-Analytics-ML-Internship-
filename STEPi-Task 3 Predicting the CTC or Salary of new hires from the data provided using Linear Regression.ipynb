# %%
import pandas as pd  #used for data analysis
import numpy as np   #To perfrom the manupulation in Data i.e. to perform a wide variety of mathematical operations on arrays. to perform a wide variety of mathematical operations on arrays. 
import datetime      #To add the Data in python by changing from object to datetime format
import matplotlib.pyplot as plt #To do some Visualizations
import seaborn as sns  #It is also used for Visualizations

# %%
data=pd.read_excel("D:/task 3/Data_file.xlsx",header=2,index_col=0)

# %%
data
# Out:
#       College       Role  City type  Previous CTC  Previous job changes  \
# S.No.
# 1      Tier 1    Manager  Non-Metro         55523                     3
# 2      Tier 2  Executive      Metro         57081                     1
# 3      Tier 2  Executive      Metro         60347                     2
# 4      Tier 3  Executive      Metro         49010                     2
# 5      Tier 3  Executive      Metro         57879                     4
# ...       ...        ...        ...           ...                   ...
# 1334   Tier 3  Executive      Metro         59661                     4
# 1335   Tier 1  Executive  Non-Metro         53714                     1
# 1336   Tier 2  Executive  Non-Metro         61957                     1
# 1337   Tier 1  Executive  Non-Metro         53203                     3
# 1338   Tier 3    Manager  Non-Metro         51820                     1
#
#        Graduation marks  Exp (Months)           CTC
# S.No.
# ...

# %%
data.head(10)
# Out:
#       College       Role  City type  Previous CTC  Previous job changes  \
# S.No.
# 1      Tier 1    Manager  Non-Metro         55523                     3
# 2      Tier 2  Executive      Metro         57081                     1
# 3      Tier 2  Executive      Metro         60347                     2
# 4      Tier 3  Executive      Metro         49010                     2
# 5      Tier 3  Executive      Metro         57879                     4
# 6      Tier 2  Executive  Non-Metro         54340                     4
# 7      Tier 2  Executive  Non-Metro         60298                     1
# 8      Tier 3  Executive  Non-Metro         49944                     2
# 9      Tier 1  Executive      Metro         53124                     4
# 10     Tier 3  Executive  Non-Metro         51141                     1
#
#        Graduation marks  Exp (Months)           CTC
# S.No.
# 1                    66            19  71406.576531
# 2                    84            18  68005.870631
# ...

# %%
data.shape
# Out:
# (1338, 8)

# %%
print(data.columns)
# Out:
# Index(['College', 'Role', 'City type', 'Previous CTC', 'Previous job changes',
#        'Graduation marks', 'Exp (Months)', 'CTC'],
#       dtype='object')

# %%
data.dtypes
# Out:
# College                  object
# Role                     object
# City type                object
# Previous CTC              int64
# Previous job changes      int64
# Graduation marks          int64
# Exp (Months)              int64
# CTC                     float64
# dtype: object

# %%
data.describe()
# Out:
#        Previous CTC  Previous job changes  Graduation marks  Exp (Months)  \
# count   1338.000000           1338.000000       1338.000000   1338.000000
# mean   55581.762332              2.525411         59.890882     39.207025
# std     6685.600553              1.123502         14.894696     14.049960
# min    36990.000000              1.000000         35.000000     18.000000
# 25%    50547.000000              2.000000         47.000000     27.000000
# 50%    55293.500000              3.000000         60.000000     39.000000
# 75%    60150.500000              4.000000         73.000000     51.000000
# max    77911.000000              4.000000         85.000000     64.000000
#
#                  CTC
# count    1338.000000
# mean    75459.338993
# std     12551.280263
# min     53020.319026
# 25%     66905.070033
# 50%     73112.640487
# 75%     80747.178420
# max    123416.994271

# %%
data.boxplot()
# Out:
# <AxesSubplot:>

# %%
data.hist()
# Out:
# array([[<AxesSubplot:title={'center':'Previous CTC'}>,
#         <AxesSubplot:title={'center':'Previous job changes'}>],
#        [<AxesSubplot:title={'center':'Graduation marks'}>,
#         <AxesSubplot:title={'center':'Exp (Months)'}>],
#        [<AxesSubplot:title={'center':'CTC'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1338 entries, 1 to 1338
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   College               1338 non-null   object
#  1   Role                  1338 non-null   object
#  2   City type             1338 non-null   object
#  3   Previous CTC          1338 non-null   int64
#  4   Previous job changes  1338 non-null   int64
#  5   Graduation marks      1338 non-null   int64
#  6   Exp (Months)          1338 non-null   int64
#  7   CTC                   1338 non-null   float64
# dtypes: float64(1), int64(4), object(3)
# memory usage: 94.1+ KB

# %%
data.isnull().sum()
# Out:
# College                 0
# Role                    0
# City type               0
# Previous CTC            0
# Previous job changes    0
# Graduation marks        0
# Exp (Months)            0
# CTC                     0
# dtype: int64

# %%
sns.pairplot(data)

# %%
corrmat=data.corr()
top_corr_features=corrmat.index
plt.figure(figsize=(25,25))
h=sns.heatmap(data[top_corr_features].corr(),annot=True,cmap='Accent')

# %%
sns.distplot(data["CTC"])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='CTC', ylabel='Density'>

# %%
n=5
data['Exp (Months)'].value_counts()[:n].index.to_list()
# Out:
# [18, 19, 50, 51, 47]

# %%
sns.barplot(x='Graduation marks', y='CTC', order =[18,19,50,51,47], data=data)
# Out:
# <AxesSubplot:xlabel='Graduation marks', ylabel='CTC'>

# %%
test=pd.read_excel("D:/task 3/Test_data_file.xlsx")

# %%
test
# Out:
#      College       Role  City type  College_T1  College_T2  Role_Manager  \
# 0     Tier 1    Manager  Non-Metro           1           0             1
# 1     Tier 2  Executive      Metro           0           1             0
# 2     Tier 2  Executive      Metro           0           1             0
# 3     Tier 3  Executive      Metro           0           0             0
# 4     Tier 3  Executive      Metro           0           0             0
# ...      ...        ...        ...         ...         ...           ...
# 1333  Tier 3  Executive      Metro           0           0             0
# 1334  Tier 1  Executive  Non-Metro           1           0             0
# 1335  Tier 2  Executive  Non-Metro           0           1             0
# 1336  Tier 1  Executive  Non-Metro           1           0             0
# 1337  Tier 3    Manager  Non-Metro           0           0             1
#
#       City_Metro  previous CTC  previous job changes  Graduation marks  ...  \
# ...

# %%
test.columns
# Out:
# Index(['College', 'Role', 'City type', 'College_T1', 'College_T2',
#        'Role_Manager', 'City_Metro', 'previous CTC', 'previous job changes',
#        'Graduation marks', 'Exp', 'Actual CTC', 'Predicted CTC', 'Unnamed: 13',
#        'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17',
#        'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21',
#        'Unnamed: 22', 'Unnamed: 23'],
#       dtype='object')

# %%
test.drop(test.columns[14:23], axis=1, inplace=True)
test.head()
# Out:
#   College       Role  City type  College_T1  College_T2  Role_Manager  \
# 0  Tier 1    Manager  Non-Metro           1           0             1
# 1  Tier 2  Executive      Metro           0           1             0
# 2  Tier 2  Executive      Metro           0           1             0
# 3  Tier 3  Executive      Metro           0           0             0
# 4  Tier 3  Executive      Metro           0           0             0
#
#    City_Metro  previous CTC  previous job changes  Graduation marks  Exp  \
# 0           0         55523                     3                66   19
# 1           1         57081                     1                84   18
# 2           1         60347                     2                52   28
# 3           1         49010                     2                81   33
# 4           1         57879                     4                74   32
#
#      Actual CTC  Predicted CTC  Unnamed: 13  Unnamed: 23
# ...

# %%
del test['Unnamed: 13']
del test['Unnamed: 23']

# %%
test.head()
# Out:
#   College       Role  City type  College_T1  College_T2  Role_Manager  \
# 0  Tier 1    Manager  Non-Metro           1           0             1
# 1  Tier 2  Executive      Metro           0           1             0
# 2  Tier 2  Executive      Metro           0           1             0
# 3  Tier 3  Executive      Metro           0           0             0
# 4  Tier 3  Executive      Metro           0           0             0
#
#    City_Metro  previous CTC  previous job changes  Graduation marks  Exp  \
# 0           0         55523                     3                66   19
# 1           1         57081                     1                84   18
# 2           1         60347                     2                52   28
# 3           1         49010                     2                81   33
# 4           1         57879                     4                74   32
#
#      Actual CTC  Predicted CTC
# 0  71406.576531            NaN
# 1  68005.870631            NaN
# ...

# %%
del test['Role']
del test['College']
del test['City type']

# %%
test.head()
# Out:
#    College_T1  College_T2  Role_Manager  City_Metro  previous CTC  \
# 0           1           0             1           0         55523
# 1           0           1             0           1         57081
# 2           0           1             0           1         60347
# 3           0           0             0           1         49010
# 4           0           0             0           1         57879
#
#    previous job changes  Graduation marks  Exp    Actual CTC  Predicted CTC
# 0                     3                66   19  71406.576531            NaN
# 1                     1                84   18  68005.870631            NaN
# 2                     2                52   28  76764.020277            NaN
# 3                     2                81   33  82092.386880            NaN
# 4                     4                74   32  73878.097729            NaN

# %%
x=test[['previous CTC','previous job changes','Graduation marks','College_T1','College_T2','Role_Manager','City_Metro']]
y=test[['Actual CTC']]

# %%
x
# Out:
#       previous CTC  previous job changes  Graduation marks  College_T1  \
# 0            55523                     3                66           1
# 1            57081                     1                84           0
# 2            60347                     2                52           0
# 3            49010                     2                81           0
# 4            57879                     4                74           0
# ...            ...                   ...               ...         ...
# 1333         59661                     4                68           0
# 1334         53714                     1                67           1
# 1335         61957                     1                47           0
# 1336         53203                     3                69           1
# 1337         51820                     1                47           0
#
#       College_T2  Role_Manager  City_Metro
# 0              0             1           0
# ...

# %%
y
# Out:
#         Actual CTC
# 0     71406.576531
# 1     68005.870631
# 2     76764.020277
# 3     82092.386880
# 4     73878.097729
# ...            ...
# 1333  69712.403655
# 1334  69298.750099
# 1335  66397.770686
# 1336  64044.382949
# 1337  83346.060961
#
# [1338 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.3, random_state=3)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
predict=lr.predict(x)
test['Predicted CTC']=predict
test.head()
# Out:
#    College_T1  College_T2  Role_Manager  City_Metro  previous CTC  \
# 0           1           0             1           0         55523
# 1           0           1             0           1         57081
# 2           0           1             0           1         60347
# 3           0           0             0           1         49010
# 4           0           0             0           1         57879
#
#    previous job changes  Graduation marks  Exp    Actual CTC  Predicted CTC
# 0                     3                66   19  71406.576531   92025.359826
# 1                     1                84   18  68005.870631   71597.094382
# 2                     2                52   28  76764.020277   72950.664569
# 3                     2                81   33  82092.386880   68644.993765
# 4                     4                74   32  73878.097729   73282.081988

# %%
predict
# Out:
# array([[92025.35982598],
#        [71597.09438224],
#        [72950.66456927],
#        ...,
#        [69704.06182373],
#        [71383.1562771 ],
#        [85132.28135295]])

# %%
sns.lmplot(x='Actual CTC', y='Predicted CTC', data=test, line_kws={'color':'pink'})

# %%
from sklearn import metrics
print("Mean Squared Error: ",metrics.mean_squared_error(y,predict))
print("Root Mean Squared Error: ",np.sqrt(metrics.mean_squared_error(y,predict)))
# Out:
# Mean Squared Error:  74943518.95345743
# Root Mean Squared Error:  8656.992488933869
